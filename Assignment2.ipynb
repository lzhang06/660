# %%
import csv

from collections import OrderedDict
from datetime import datetime
class DataFrame(object):

    @classmethod
    def from_csv(cls, file_path, delimiting_character=',', quote_character='"'):
        with open(file_path, 'rU') as infile:
            reader = csv.reader(infile, delimiter=delimiting_character, quotechar=quote_character)
            data = []

            for row in reader:
                data.append(row)

            return cls(list_of_lists=data)



    def __init__(self, list_of_lists, header=True):
        #A2-task 1
        def unique_values(g):
            s =set()
            for x in g:
                if x in s: 
                    return False
                s.add(x)
            return True
        
        if header:
            self.header = list_of_lists[0]
            #task 1
            if not unique_values(self.header):
                raise Exception('Error: Not Unique')
            
            self.data = list_of_lists[1:]
        else:
            self.data = list_of_lists
            self.header = ['column' + str(index + 1) for index, column in enumerate(self.data[0])]
        
        #A2-task2
        
        for row in self.data:
            tmp = []
            for s in row:
                if isinstance(s , str):
                    tmp.append(s.strip())
                else:
                    tmp.append(s)
            row[:] = tmp[:]


        self.data = [OrderedDict(zip(self.header, row)) for row in self.data]
    
    def __getitem__(self, item):
        # this is for rows only
        if isinstance(item, (int, slice)):
            return self.data[item]

        # this is for columns only
        elif isinstance(item, str):
            return [row[item] for row in self.data]

        # this is for rows and columns
        elif isinstance(item, tuple):
            if isinstance(item[0], list) or isinstance(item[1], list):

                if isinstance(item[0], list):
                    rowz = [row for index, row in enumerate(self.data) if index in item[0]]
                else:
                    rowz = self.data[item[0]]

                if isinstance(item[1], list):
                    if all([isinstance(thing, int) for thing in item[1]]):
                        return [[column_value for index, column_value in enumerate([value for value in row.values()]) if index in item[1]] for row in rowz]
                    elif all([isinstance(thing, str) for thing in item[1]]):
                        return [[row[column_name] for column_name in item[1]] for row in rowz]
                    else:
                        raise TypeError('What the hell is this?')

                else:
                    return [[value for value in row.items()][item[1]] for row in rowz]
            else:
                if isinstance(item[1],  slice) or isinstance(item[0], slice):
                    return [[value for value in row.items()][item[1]] for row in self.data[item[0]]]
                
                elif isinstance(item[1], int):
                    return [row for row in self.data[item[0]].items()][item[1]]
                
                
                elif isinstance(item[1], str):
                    return self[item[1]][item[0]]
                else:
                    raise TypeError('I don\'t know how to handle this...')

        # only for lists of column names
        elif isinstance(item, list):
            return [[row[column_name] for column_name in item] for row in self.data]
        
     
        

        
    def get_rows_where_column_has_value(self, column_name, value, index_only=False):
        if index_only:
            return [index for index, row_value in enumerate(self[column_name]) if row_value==value]
        else:
            return [row for row in self.data if row[column_name]==value]

    #A2-task3
    def type_valid(self, column_name):
        from datetime import datetime
        if isinstance(self[column_name][0], (int, float, datetime)):
            return True
        else:
            return False
    
    def min(self, column_name):
        if not self.type_valid(column_name):
            raise Exception("Data Invalid Error")
        
        return min(self[column_name])
    
    def max(self, column_name):
        if not self.type_valid(column_name):
            raise Exception("Data Invalid Error")
        return max(self[column_name])
    
    def median(self, column_name):
        if not self.type_valid(column_name):
            raise Exception("Data Invalid Error")
        else:
            self[column_name].sort()
            lens = len(self[column_name])
            if lens%2 == 0:
                midl = lens/2
                res = self[column_name][int(midl)]
            else:
                odd = (lens /2)-1
                even = (lens /2)
                res = float(self[column_name][int(odd)] + self[column_name][int(even)]) / float(2)
        return res
    
    def mean(self, column_name):
        if not self.type_valid(column_name):
            raise Exception("Data Invalid Error")
        return float(sum(self[column_name])) / max(len(self[column_name]), 1)
    
    def _ss(self, column_name):
        #Return sum of square deviation of sequence data
        if not self.type_valid(column_name):
            raise Exception("Data Invalid Error")
        else:
            sum_value = 0
            mean_value =self.mean(column_name)
            for index, row_value in enumerate(self[column_name]):
                ss = (row_value-mean_value)**2
                sum_value += ss
            return ss
    
    def stdev(self, column_name):
        '''Calculate the population standard deviation'''
        n = len(self[column_name])
        ss = self._ss(column_name)
        svar = ss/n
        return svar**0.5
            
    
    
        
    #A2-task 4 add_rows                 
    def add_rows(self, list_of_lists):
        
        for l in list_of_lists:
            if len(l) != len(self.data[0]):
                raise Exception("The length of input does not match the column number")
                
        self.data = self.data + [OrderedDict(zip(self.header, row)) for row in list_of_lists] 
        
        
    #A2-task 5 add_column
    def add_column(self, list_of_values, column_name):
        if len(list_of_values) != len(self.data):
            raise Exception("The length of input does not match the column number")
        
        for row in self.data[::-1]:
            row[column_name] = list_of_values.pop()
            
    #assignment3 
    #task1
    def sort_by(self, column_name, aescending):
        if aescending == True:
            return sorted(self[column_name])
        else:
            return sorted(self[column_name], reverse = True)
        
    
     #A3-task2
    def comparsion_boolean(self, column_name, threshold):
        boolean_list = []
        for index, row_value in enumerate(self[column_name]):
            boolean_value  = threshold > row_value
            boolean_list.append(boolean_value)
        return [index, row_value for index, row_value in enumerate(boolean_list) if row_value]   
           

    
infile = open('/Users/Lucinda/Desktop/660/data_source/SalesJan2009.csv')
lines = infile.readlines()
lines = [lines[i].strip('\n') for i in range(len(lines))]
data = [l.split(',') for l in lines]
things = lines[559].split('"')
data[559] = things[0].split(',')[:-1] +[things[1]] + things[-1].split(',')[1:]
data[559][2] = data[559][2].replace(',','')

for p in range(1, len(data)):
    data[p][2] = float(data[p][2])
    data[p][0] = datetime.strptime(data[p][0], '%m/%d/%y %H:%M')

    
    

df = DataFrame(list_of_lists=data)
# get the 5th row
fifth = df[4]
sliced = df[4:10]

# get item definition for df [row, column]

# get the third column
tupled = df[:, 2]
tupled_slices = df[0:5, :3]

tupled_bits = df[[1, 4], [1, 4]]


# adding header for data with no header
#df = DataFrame(list_of_lists=data[1:], header=False)

# fetch columns by name
# named = df['column1']
# named_multi = df[['column1', 'column7']]

# #fetch rows and (columns by name)
# named_rows_and_columns = df[:5, 'column7']
# named_rows_and_multi_columns = df[:5, ['column4', 'column7']]


#testing from_csv class method
# df = DataFrame.from_csv('/Users/Lucinda/Desktop/660/data_source/SalesJan2009.csv')
# rows = df.get_rows_where_column_has_value('Payment_Type', 'Visa')
# indices = df.get_rows_where_column_has_value('Payment_Type', 'Visa', index_only=True)

# rows_way2 = df[indices, ['Product', 'Country']]
# Out:
#   File "<ipython-input-141-7d25c5733d79>", line 204
#     return [index, row_value for index, row_value in enumerate(boolean_list) if row_value]
#                                ^
# SyntaxError: invalid syntax

# %%
df.data
# Out:
# [OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 6, 17)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'carolina'),
#               ('City', 'Basildon'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/2/09 6:00'),
#               ('Last_Login', '1/2/09 6:08'),
#               ('Latitude', '51.5'),
#               ('Longitude', '-1.1166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 4, 53)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Betina'),
#               ('City', 'Parkville'),
#               ('State', 'MO'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/2/09 4:42'),
#               ('Last_Login', '1/2/09 7:49'),
#               ('Latitude', '39.195'),
#               ('Longitude', '-94.68194')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 13, 8)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Federica e Andrea'),
#               ('City', 'Astoria'),
#               ('State', 'OR'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/1/09 16:21'),
#               ('Last_Login', '1/3/09 12:32'),
#               ('Latitude', '46.18806'),
#               ('Longitude', '-123.83')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 14, 44)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Gouya'),
#               ('City', 'Echuca'),
#               ('State', 'Victoria'),
#               ('Country', 'Australia'),
#               ('Account_Created', '9/25/05 21:13'),
#               ('Last_Login', '1/3/09 14:22'),
#               ('Latitude', '-36.1333333'),
#               ('Longitude', '144.75')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 12, 56)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Gerd W'),
#               ('City', 'Cahaba Heights'),
#               ('State', 'AL'),
#               ('Country', 'United States'),
#               ('Account_Created', '11/15/08 15:47'),
#               ('Last_Login', '1/4/09 12:45'),
#               ('Latitude', '33.52056'),
#               ('Longitude', '-86.8025')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 13, 19)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'LAURENCE'),
#               ('City', 'Mickleton'),
#               ('State', 'NJ'),
#               ('Country', 'United States'),
#               ('Account_Created', '9/24/08 15:19'),
#               ('Last_Login', '1/4/09 13:04'),
#               ('Latitude', '39.79'),
#               ('Longitude', '-75.23806')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 20, 11)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Fleur'),
#               ('City', 'Peoria'),
#               ('State', 'IL'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/3/09 9:38'),
#               ('Last_Login', '1/4/09 19:45'),
#               ('Latitude', '40.69361'),
#               ('Longitude', '-89.58889')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 20, 9)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'adam'),
#               ('City', 'Martin'),
#               ('State', 'TN'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/2/09 17:43'),
#               ('Last_Login', '1/4/09 20:01'),
#               ('Latitude', '36.34333'),
#               ('Longitude', '-88.85028')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 13, 17)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Renee Elisabeth'),
#               ('City', 'Tel Aviv'),
#               ('State', 'Tel Aviv'),
#               ('Country', 'Israel'),
#               ('Account_Created', '1/4/09 13:03'),
#               ('Last_Login', '1/4/09 22:10'),
#               ('Latitude', '32.0666667'),
#               ('Longitude', '34.7666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 14, 11)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Aidan'),
#               ('City', 'Chatou'),
#               ('State', 'Ile-de-France'),
#               ('Country', 'France'),
#               ('Account_Created', '6/3/08 4:22'),
#               ('Last_Login', '1/5/09 1:17'),
#               ('Latitude', '48.8833333'),
#               ('Longitude', '2.15')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 2, 42)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Stacy'),
#               ('City', 'New York'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/5/09 2:23'),
#               ('Last_Login', '1/5/09 4:59'),
#               ('Latitude', '40.71417'),
#               ('Longitude', '-74.00639')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 5, 39)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Heidi'),
#               ('City', 'Eindhoven'),
#               ('State', 'Noord-Brabant'),
#               ('Country', 'Netherlands'),
#               ('Account_Created', '1/5/09 4:55'),
#               ('Last_Login', '1/5/09 8:15'),
#               ('Latitude', '51.45'),
#               ('Longitude', '5.4666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 9, 16)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Sean'),
#               ('City', 'Shavano Park'),
#               ('State', 'TX'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/2/09 8:32'),
#               ('Last_Login', '1/5/09 9:05'),
#               ('Latitude', '29.42389'),
#               ('Longitude', '-98.49333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 10, 8)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Georgia'),
#               ('City', 'Eagle'),
#               ('State', 'ID'),
#               ('Country', 'United States'),
#               ('Account_Created', '11/11/08 15:53'),
#               ('Last_Login', '1/5/09 10:05'),
#               ('Latitude', '43.69556'),
#               ('Longitude', '-116.35306')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 14, 18)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Richard'),
#               ('City', 'Riverside'),
#               ('State', 'NJ'),
#               ('Country', 'United States'),
#               ('Account_Created', '12/9/08 12:07'),
#               ('Last_Login', '1/5/09 11:01'),
#               ('Latitude', '40.03222'),
#               ('Longitude', '-74.95778')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 1, 5)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Leanne'),
#               ('City', 'Julianstown'),
#               ('State', 'Meath'),
#               ('Country', 'Ireland'),
#               ('Account_Created', '1/4/09 0:00'),
#               ('Last_Login', '1/5/09 13:36'),
#               ('Latitude', '53.6772222'),
#               ('Longitude', '-6.3191667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 11, 37)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Janet'),
#               ('City', 'Ottawa'),
#               ('State', 'Ontario'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/5/09 9:35'),
#               ('Last_Login', '1/5/09 19:24'),
#               ('Latitude', '45.4166667'),
#               ('Longitude', '-75.7')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 5, 2)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'barbara'),
#               ('City', 'Hyderabad'),
#               ('State', 'Andhra Pradesh'),
#               ('Country', 'India'),
#               ('Account_Created', '1/6/09 2:41'),
#               ('Last_Login', '1/6/09 7:52'),
#               ('Latitude', '17.3833333'),
#               ('Longitude', '78.4666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 7, 45)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Sabine'),
#               ('City', 'London'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/6/09 7:00'),
#               ('Last_Login', '1/6/09 9:17'),
#               ('Latitude', '51.52721'),
#               ('Longitude', '0.14559')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 7, 35)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Hani'),
#               ('City', 'Salt Lake City'),
#               ('State', 'UT'),
#               ('Country', 'United States'),
#               ('Account_Created', '12/30/08 5:44'),
#               ('Last_Login', '1/6/09 10:52'),
#               ('Latitude', '40.76083'),
#               ('Longitude', '-111.89028')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 12, 56)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Jeremy'),
#               ('City', 'Manchester'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/6/09 10:58'),
#               ('Last_Login', '1/6/09 13:31'),
#               ('Latitude', '53.5'),
#               ('Longitude', '-2.2166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 11, 5)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Janis'),
#               ('City', 'Ballynora'),
#               ('State', 'Cork'),
#               ('Country', 'Ireland'),
#               ('Account_Created', '12/10/07 12:37'),
#               ('Last_Login', '1/7/09 1:52'),
#               ('Latitude', '51.8630556'),
#               ('Longitude', '-8.58')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 4, 10)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Nicola'),
#               ('City', 'Roodepoort'),
#               ('State', 'Gauteng'),
#               ('Country', 'South Africa'),
#               ('Account_Created', '1/5/09 2:33'),
#               ('Last_Login', '1/7/09 5:13'),
#               ('Latitude', '-26.1666667'),
#               ('Longitude', '27.8666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 7, 18)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'asuman'),
#               ('City', 'Chula Vista'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/6/09 7:07'),
#               ('Last_Login', '1/7/09 7:08'),
#               ('Latitude', '32.64'),
#               ('Longitude', '-117.08333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 1, 11)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Lena'),
#               ('City', 'Kuopio'),
#               ('State', 'Ita-Suomen Laani'),
#               ('Country', 'Finland'),
#               ('Account_Created', '12/31/08 2:48'),
#               ('Last_Login', '1/7/09 10:20'),
#               ('Latitude', '62.9'),
#               ('Longitude', '27.6833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 2, 24)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Lisa'),
#               ('City', 'Sugar Land'),
#               ('State', 'TX'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/1/09 1:56'),
#               ('Last_Login', '1/7/09 10:52'),
#               ('Latitude', '29.61944'),
#               ('Longitude', '-95.63472')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 8, 8)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Bryan Kerrene'),
#               ('City', 'New York'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/7/09 7:39'),
#               ('Last_Login', '1/7/09 12:38'),
#               ('Latitude', '40.71417'),
#               ('Longitude', '-74.00639')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 2, 57)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'chris'),
#               ('City', 'London'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/3/08 7:23'),
#               ('Last_Login', '1/7/09 13:14'),
#               ('Latitude', '51.52721'),
#               ('Longitude', '0.14559')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 20, 21)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Maxine'),
#               ('City', 'Morton'),
#               ('State', 'IL'),
#               ('Country', 'United States'),
#               ('Account_Created', '10/24/08 6:48'),
#               ('Last_Login', '1/7/09 20:49'),
#               ('Latitude', '40.61278'),
#               ('Longitude', '-89.45917')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 0, 42)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Family'),
#               ('City', 'Los Gatos'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 0:28'),
#               ('Last_Login', '1/8/09 3:39'),
#               ('Latitude', '37.22667'),
#               ('Longitude', '-121.97361')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 3, 56)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Katherine'),
#               ('City', 'New York'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 3:33'),
#               ('Last_Login', '1/8/09 6:19'),
#               ('Latitude', '40.71417'),
#               ('Longitude', '-74.00639')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 3, 16)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Linda'),
#               ('City', 'Miami'),
#               ('State', 'FL'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 3:06'),
#               ('Last_Login', '1/8/09 6:34'),
#               ('Latitude', '25.77389'),
#               ('Longitude', '-80.19389')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 1, 59)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'SYLVIA'),
#               ('City', 'Vesenaz'),
#               ('State', 'Geneve'),
#               ('Country', 'Switzerland'),
#               ('Account_Created', '11/28/07 11:56'),
#               ('Last_Login', '1/8/09 7:20'),
#               ('Latitude', '46.2333333'),
#               ('Longitude', '6.2')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 9, 3)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Sheila'),
#               ('City', 'Brooklyn'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/3/09 8:47'),
#               ('Last_Login', '1/8/09 10:38'),
#               ('Latitude', '40.65'),
#               ('Longitude', '-73.95')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 13, 17)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Stephanie'),
#               ('City', 'Badhoevedorp'),
#               ('State', 'Noord-Holland'),
#               ('Country', 'Netherlands'),
#               ('Account_Created', '1/5/09 12:45'),
#               ('Last_Login', '1/8/09 11:45'),
#               ('Latitude', '52.3333333'),
#               ('Longitude', '4.7833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 7, 46)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Kelly'),
#               ('City', 'Reston'),
#               ('State', 'VA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/6/09 7:30'),
#               ('Last_Login', '1/8/09 12:40'),
#               ('Latitude', '38.96861'),
#               ('Longitude', '-77.34139')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 20, 0)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'James'),
#               ('City', 'Burpengary'),
#               ('State', 'Queensland'),
#               ('Country', 'Australia'),
#               ('Account_Created', '12/10/08 19:53'),
#               ('Last_Login', '1/8/09 17:58'),
#               ('Latitude', '-27.1666667'),
#               ('Longitude', '152.95')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 16, 24)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'jennifer'),
#               ('City', 'Phoenix'),
#               ('State', 'AZ'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 15:57'),
#               ('Last_Login', '1/8/09 18:30'),
#               ('Latitude', '33.44833'),
#               ('Longitude', '-112.07333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 9, 6, 39)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Anneli'),
#               ('City', 'Houston'),
#               ('State', 'TX'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/9/09 5:09'),
#               ('Last_Login', '1/9/09 7:11'),
#               ('Latitude', '29.76306'),
#               ('Longitude', '-95.36306')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 22, 19)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Ritz'),
#               ('City', 'Pittsfield'),
#               ('State', 'VT'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/6/09 12:00'),
#               ('Last_Login', '1/9/09 10:05'),
#               ('Latitude', '43.77222'),
#               ('Longitude', '-72.81333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 23, 0)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Sylvia'),
#               ('City', 'Pittsfield'),
#               ('State', 'VT'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/6/09 12:00'),
#               ('Last_Login', '1/9/09 10:05'),
#               ('Latitude', '43.77222'),
#               ('Longitude', '-72.81333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 7, 44)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Marie'),
#               ('City', 'Ball Ground'),
#               ('State', 'GA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/7/09 5:35'),
#               ('Last_Login', '1/9/09 10:52'),
#               ('Latitude', '34.33806'),
#               ('Longitude', '-84.37667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 13, 24)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Mehmet Fatih'),
#               ('City', 'Helsingor'),
#               ('State', 'Frederiksborg'),
#               ('Country', 'Denmark'),
#               ('Account_Created', '1/3/09 12:47'),
#               ('Last_Login', '1/9/09 11:14'),
#               ('Latitude', '56.0333333'),
#               ('Longitude', '12.6166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 15, 12)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Anabela'),
#               ('City', 'Flossmoor'),
#               ('State', 'IL'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/5/09 19:55'),
#               ('Last_Login', '1/9/09 16:03'),
#               ('Latitude', '41.54278'),
#               ('Longitude', '-87.68472')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 20, 15)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Nicole'),
#               ('City', 'Houston'),
#               ('State', 'TX'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/7/09 17:17'),
#               ('Last_Login', '1/9/09 20:02'),
#               ('Latitude', '29.76306'),
#               ('Longitude', '-95.36306')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 10, 11)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Christiane'),
#               ('City', 'Delray Beach'),
#               ('State', 'FL'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/3/09 9:27'),
#               ('Last_Login', '1/10/09 9:46'),
#               ('Latitude', '26.46111'),
#               ('Longitude', '-80.07306')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 9, 15, 58)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Sari'),
#               ('City', 'Newbury'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/9/09 14:53'),
#               ('Last_Login', '1/10/09 13:16'),
#               ('Latitude', '51.4'),
#               ('Longitude', '-1.3166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 13, 11)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'simone'),
#               ('City', 'Kobenhavn'),
#               ('State', 'Kobenhavn'),
#               ('Country', 'Denmark'),
#               ('Account_Created', '10/31/08 0:31'),
#               ('Last_Login', '1/10/09 13:24'),
#               ('Latitude', '55.6666667'),
#               ('Longitude', '12.5833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 12, 57)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Vanessa'),
#               ('City', 'Sandy Springs'),
#               ('State', 'GA'),
#               ('Country', 'United States'),
#               ('Account_Created', '2/7/07 20:16'),
#               ('Last_Login', '1/10/09 14:09'),
#               ('Latitude', '33.92417'),
#               ('Longitude', '-84.37861')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 14, 43)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Anupam'),
#               ('City', 'Kinsaley'),
#               ('State', 'Dublin'),
#               ('Country', 'Ireland'),
#               ('Account_Created', '1/9/09 11:38'),
#               ('Last_Login', '1/10/09 14:37'),
#               ('Latitude', '53.4247222'),
#               ('Longitude', '-6.1758333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 12, 5)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Karina'),
#               ('City', 'Fort Lauderdale'),
#               ('State', 'FL'),
#               ('Country', 'United States'),
#               ('Account_Created', '7/1/08 12:53'),
#               ('Last_Login', '1/10/09 16:33'),
#               ('Latitude', '26.12194'),
#               ('Longitude', '-80.14361')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 1, 20)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Frank'),
#               ('City', 'Melbourne'),
#               ('State', 'Victoria'),
#               ('Country', 'Australia'),
#               ('Account_Created', '1/2/09 17:51'),
#               ('Last_Login', '1/10/09 18:27'),
#               ('Latitude', '-37.8166667'),
#               ('Longitude', '144.9666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 14, 56)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Angela'),
#               ('City', 'Ankeny'),
#               ('State', 'IA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 3:06'),
#               ('Last_Login', '1/10/09 19:41'),
#               ('Latitude', '41.72972'),
#               ('Longitude', '-93.60556')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 10, 1)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Darren'),
#               ('City', 'Pittsboro'),
#               ('State', 'NC'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/7/09 9:04'),
#               ('Last_Login', '1/10/09 20:02'),
#               ('Latitude', '35.72'),
#               ('Longitude', '-79.1775')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 1, 26)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Nikki'),
#               ('City', 'New Rochelle'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/1/09 0:58'),
#               ('Last_Login', '1/10/09 21:31'),
#               ('Latitude', '40.91139'),
#               ('Longitude', '-73.78278')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 11, 2, 4)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'chris'),
#               ('City', 'Gold Coast'),
#               ('State', 'Queensland'),
#               ('Country', 'Australia'),
#               ('Account_Created', '1/11/09 0:33'),
#               ('Last_Login', '1/11/09 2:11'),
#               ('Latitude', '-28'),
#               ('Longitude', '153.4333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 11, 14, 17)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Stephanie'),
#               ('City', 'Brussels'),
#               ('State', 'Brussels (Bruxelles)'),
#               ('Country', 'Belgium'),
#               ('Account_Created', '1/11/09 13:39'),
#               ('Last_Login', '1/11/09 13:39'),
#               ('Latitude', '50.8333333'),
#               ('Longitude', '4.3333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 21, 38)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Anushka'),
#               ('City', 'Maple Ridge District Municipality'),
#               ('State', 'British Columbia'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/10/09 21:17'),
#               ('Last_Login', '1/11/09 19:32'),
#               ('Latitude', '49.25'),
#               ('Longitude', '-122.5')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 6, 18)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'June'),
#               ('City', 'Beachwood'),
#               ('State', 'OH'),
#               ('Country', 'United States'),
#               ('Account_Created', '2/23/06 11:56'),
#               ('Last_Login', '1/11/09 19:35'),
#               ('Latitude', '41.46444'),
#               ('Longitude', '-81.50889')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 8, 39)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Baybars'),
#               ('City', 'Prince Albert'),
#               ('State', 'Saskatchewan'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/3/09 17:17'),
#               ('Last_Login', '1/11/09 21:05'),
#               ('Latitude', '53.2'),
#               ('Longitude', '-105.75')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 0, 31)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Bonnie'),
#               ('City', 'Saltsjobaden'),
#               ('State', 'Stockholm'),
#               ('Country', 'Sweden'),
#               ('Account_Created', '1/4/09 23:45'),
#               ('Last_Login', '1/12/09 0:37'),
#               ('Latitude', '59.2833333'),
#               ('Longitude', '18.3')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 6, 7)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Cindy'),
#               ('City', 'Kemble'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '12/30/08 10:21'),
#               ('Last_Login', '1/12/09 2:24'),
#               ('Latitude', '51.6766667'),
#               ('Longitude', '-2.0180556')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 3, 25)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'chrissy'),
#               ('City', 'W Lebanon'),
#               ('State', 'NH'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/12/09 3:12'),
#               ('Last_Login', '1/12/09 3:22'),
#               ('Latitude', '43.64917'),
#               ('Longitude', '-72.31083')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 13, 56)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Tamar'),
#               ('City', 'Headley'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '11/29/07 9:23'),
#               ('Last_Login', '1/12/09 5:38'),
#               ('Latitude', '51.1166667'),
#               ('Longitude', '-0.8166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 0, 12)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Deirdre'),
#               ('City', 'Lausanne'),
#               ('State', 'Vaud'),
#               ('Country', 'Switzerland'),
#               ('Account_Created', '12/1/08 6:25'),
#               ('Last_Login', '1/12/09 6:55'),
#               ('Latitude', '46.5333333'),
#               ('Longitude', '6.6666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 5, 18)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Bernadett'),
#               ('City', 'Southampton'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/12/09 4:45'),
#               ('Last_Login', '1/12/09 8:08'),
#               ('Latitude', '50.9'),
#               ('Longitude', '-1.4')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 15, 16)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Dottie'),
#               ('City', 'Woodsboro'),
#               ('State', 'MD'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/8/09 14:56'),
#               ('Last_Login', '1/12/09 9:29'),
#               ('Latitude', '39.53306'),
#               ('Longitude', '-77.315')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 11, 11, 33)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Stefan'),
#               ('City', 'Stavanger'),
#               ('State', 'Rogaland'),
#               ('Country', 'Norway'),
#               ('Account_Created', '1/11/09 9:02'),
#               ('Last_Login', '1/12/09 10:37'),
#               ('Latitude', '58.9666667'),
#               ('Longitude', '5.75')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 20, 22)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Gina'),
#               ('City', 'Red Deer'),
#               ('State', 'Alberta'),
#               ('Country', 'Canada'),
#               ('Account_Created', '11/23/08 19:30'),
#               ('Last_Login', '1/12/09 12:24'),
#               ('Latitude', '52.2666667'),
#               ('Longitude', '-113.8')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 22, 0)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Lynne'),
#               ('City', 'Memphis'),
#               ('State', 'TN'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/2/09 21:04'),
#               ('Last_Login', '1/12/09 13:18'),
#               ('Latitude', '35.14944'),
#               ('Longitude', '-90.04889')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 13, 52)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Tammy'),
#               ('City', 'Morges'),
#               ('State', 'Vaud'),
#               ('Country', 'Switzerland'),
#               ('Account_Created', '1/5/09 5:55'),
#               ('Last_Login', '1/12/09 14:04'),
#               ('Latitude', '46.5166667'),
#               ('Longitude', '6.5')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 20, 32)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Kim'),
#               ('City', 'Calgary'),
#               ('State', 'Alberta'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/8/09 20:21'),
#               ('Last_Login', '1/12/09 14:07'),
#               ('Latitude', '51.0833333'),
#               ('Longitude', '-114.0833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 13, 34)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Bruce'),
#               ('City', 'Belleville'),
#               ('State', 'Ontario'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/6/09 14:38'),
#               ('Last_Login', '1/12/09 18:31'),
#               ('Latitude', '44.1666667'),
#               ('Longitude', '-77.3833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 11, 13, 8)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Rosa Maria'),
#               ('City', 'Cincinnati'),
#               ('State', 'OH'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/11/09 12:38'),
#               ('Last_Login', '1/12/09 18:44'),
#               ('Latitude', '39.16194'),
#               ('Longitude', '-84.45694')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 19, 4)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Lydia'),
#               ('City', 'Comox'),
#               ('State', 'British Columbia'),
#               ('Country', 'Canada'),
#               ('Account_Created', '9/20/08 20:53'),
#               ('Last_Login', '1/12/09 19:01'),
#               ('Latitude', '49.6833333'),
#               ('Longitude', '-124.9333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 13, 41)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Eric'),
#               ('City', 'Gasperich'),
#               ('State', 'Luxembourg'),
#               ('Country', 'Luxembourg'),
#               ('Account_Created', '1/12/09 13:16'),
#               ('Last_Login', '1/13/09 1:03'),
#               ('Latitude', '49.5855556'),
#               ('Longitude', '6.1230556')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 11, 10, 38)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'AnaPaula'),
#               ('City', 'Helens Bay'),
#               ('State', 'Northern Ireland'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '9/4/08 9:26'),
#               ('Last_Login', '1/13/09 2:36'),
#               ('Latitude', '54.65'),
#               ('Longitude', '-5.7333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 13, 5, 57)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Robin'),
#               ('City', 'Milan'),
#               ('State', 'Lombardy'),
#               ('Country', 'Italy'),
#               ('Account_Created', '10/15/08 5:31'),
#               ('Last_Login', '1/13/09 5:55'),
#               ('Latitude', '45.4666667'),
#               ('Longitude', '9.2')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 13, 6, 13)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Gitte'),
#               ('City', 'Staten Island'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/13/09 5:17'),
#               ('Last_Login', '1/13/09 7:33'),
#               ('Latitude', '40.63667'),
#               ('Longitude', '-74.15917')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 13, 14)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Dr. Claudia'),
#               ('City', 'Oslo'),
#               ('State', 'Oslo'),
#               ('Country', 'Norway'),
#               ('Account_Created', '1/8/09 12:47'),
#               ('Last_Login', '1/13/09 10:49'),
#               ('Latitude', '59.9166667'),
#               ('Longitude', '10.75')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 11, 41)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Crystal'),
#               ('City', 'Farmington'),
#               ('State', 'Michigan'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/1/09 12:00'),
#               ('Last_Login', '1/13/09 18:34'),
#               ('Latitude', '42.46444'),
#               ('Longitude', '-83.37639')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 19, 50)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Delphine'),
#               ('City', 'Santa Monica'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/3/09 12:04'),
#               ('Last_Login', '1/13/09 20:17'),
#               ('Latitude', '34.01944'),
#               ('Longitude', '-118.49028')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 20, 28)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'nathalie'),
#               ('City', 'Calgary'),
#               ('State', 'Alberta'),
#               ('Country', 'Canada'),
#               ('Account_Created', '1/1/09 20:11'),
#               ('Last_Login', '1/13/09 21:11'),
#               ('Latitude', '51.0833333'),
#               ('Longitude', '-114.0833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 15, 22)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Lindi'),
#               ('City', 'Vancouver'),
#               ('State', 'British Columbia'),
#               ('Country', 'Canada'),
#               ('Account_Created', '2/20/08 22:45'),
#               ('Last_Login', '1/13/09 23:02'),
#               ('Latitude', '49.25'),
#               ('Longitude', '-123.1333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 3, 3)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Valda'),
#               ('City', 'Irvine'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/12/09 2:48'),
#               ('Last_Login', '1/14/09 1:07'),
#               ('Latitude', '33.66944'),
#               ('Longitude', '-117.82222')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 8, 58)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Marcia'),
#               ('City', 'Telgte'),
#               ('State', 'Nordrhein-Westfalen'),
#               ('Country', 'Germany'),
#               ('Account_Created', '9/1/08 3:39'),
#               ('Last_Login', '1/14/09 2:07'),
#               ('Latitude', '52.3333333'),
#               ('Longitude', '7.9')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 10, 14, 3)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Kevin'),
#               ('City', 'Cheltenham'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '3/13/06 4:56'),
#               ('Last_Login', '1/14/09 2:22'),
#               ('Latitude', '51.9'),
#               ('Longitude', '-2.0833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 13, 11, 26)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Clare'),
#               ('City', 'Keller'),
#               ('State', 'VA'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/13/09 11:15'),
#               ('Last_Login', '1/14/09 2:39'),
#               ('Latitude', '37.61917'),
#               ('Longitude', '-75.76417')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 12, 18)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Alice'),
#               ('City', 'Nakskov'),
#               ('State', 'Storstrom'),
#               ('Country', 'Denmark'),
#               ('Account_Created', '12/5/07 11:37'),
#               ('Last_Login', '1/14/09 4:05'),
#               ('Latitude', '54.8333333'),
#               ('Longitude', '11.15')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 14, 4, 54)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'ZENA'),
#               ('City', 'Honolulu'),
#               ('State', 'HI'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/14/09 4:34'),
#               ('Last_Login', '1/14/09 4:43'),
#               ('Latitude', '21.30694'),
#               ('Longitude', '-157.85833')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 6, 17, 15)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Andrea'),
#               ('City', 'Bubuieci'),
#               ('State', 'Chisinau'),
#               ('Country', 'Moldova'),
#               ('Account_Created', '12/24/08 17:31'),
#               ('Last_Login', '1/14/09 10:27'),
#               ('Latitude', '46.985'),
#               ('Longitude', '28.9425')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 13, 56)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Rennae'),
#               ('City', 'Amelia Island'),
#               ('State', 'FL'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/3/09 12:30'),
#               ('Last_Login', '1/14/09 13:03'),
#               ('Latitude', '30.66944'),
#               ('Longitude', '-81.46278')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 7, 54)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Gerhard'),
#               ('City', 'Alliston'),
#               ('State', 'Ontario'),
#               ('Country', 'Canada'),
#               ('Account_Created', '10/21/05 21:49'),
# ...
#               ('Payment_Type', 'Visa'),
#               ('Name', 'jingyan'),
#               ('City', 'Bristol'),
#               ('State', 'RI'),
#               ('Country', 'United States'),
#               ('Account_Created', '3/12/07 15:14'),
#               ('Last_Login', '2/27/09 17:13'),
#               ('Latitude', '41.67694'),
#               ('Longitude', '-71.26667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 17, 24)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'clara'),
#               ('City', 'Perth'),
#               ('State', 'Western Australia'),
#               ('Country', 'Australia'),
#               ('Account_Created', '1/1/09 21:20'),
#               ('Last_Login', '2/27/09 18:43'),
#               ('Latitude', '-31.9333333'),
#               ('Longitude', '115.8333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 18, 15)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Selma'),
#               ('City', 'Greenville'),
#               ('State', 'TX'),
#               ('Country', 'United States'),
#               ('Account_Created', '1/5/09 18:16'),
#               ('Last_Login', '2/27/09 19:07'),
#               ('Latitude', '33.13833'),
#               ('Longitude', '-96.11056')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 3, 21, 19)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Doug and Tina'),
#               ('City', 'Pls Vrds Est'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '12/24/07 22:59'),
#               ('Last_Login', '2/27/09 21:40'),
#               ('Latitude', '33.80056'),
#               ('Longitude', '-118.38917')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 5, 13)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Lauren'),
#               ('City', 'Hradec Kralove'),
#               ('State', 'East Bohemia'),
#               ('Country', 'Czech Republic'),
#               ('Account_Created', '3/5/06 0:51'),
#               ('Last_Login', '2/27/09 23:30'),
#               ('Latitude', '50.2116667'),
#               ('Longitude', '15.8441667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 9, 28)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Jen'),
#               ('City', 'Maidstone'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '7/18/05 14:17'),
#               ('Last_Login', '2/28/09 2:28'),
#               ('Latitude', '51.2666667'),
#               ('Longitude', '0.5166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 2, 4, 34)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'gladys'),
#               ('City', 'Saint Albans'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/10/06 4:20'),
#               ('Last_Login', '2/28/09 3:43'),
#               ('Latitude', '51.75'),
#               ('Longitude', '-0.3333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 22, 11, 10)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Gustavo'),
#               ('City', 'Voluntari'),
#               ('State', 'Bucuresti'),
#               ('Country', 'Romania'),
#               ('Account_Created', '7/28/08 11:12'),
#               ('Last_Login', '2/28/09 7:52'),
#               ('Latitude', '44.4666667'),
#               ('Longitude', '26.1333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 12, 6)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Erica'),
#               ('City', 'Nadur'),
#               ('State', ''),
#               ('Country', 'Malta'),
#               ('Account_Created', '3/30/06 2:02'),
#               ('Last_Login', '2/28/09 7:59'),
#               ('Latitude', '36.0377778'),
#               ('Longitude', '14.2941667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 29, 13, 25)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'Hale'),
#               ('City', 'Morrison'),
#               ('State', 'CO'),
#               ('Country', 'United States'),
#               ('Account_Created', '11/3/05 18:14'),
#               ('Last_Login', '2/28/09 8:27'),
#               ('Latitude', '39.65361'),
#               ('Longitude', '-105.19056')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 27, 2, 57)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Rosemary'),
#               ('City', 'Cobham'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/27/09 2:50'),
#               ('Last_Login', '2/28/09 9:22'),
#               ('Latitude', '51.3833333'),
#               ('Longitude', '0.4')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 13, 19)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Darian'),
#               ('City', 'Izmir'),
#               ('State', 'Izmir'),
#               ('Country', 'Turkey'),
#               ('Account_Created', '8/26/08 7:33'),
#               ('Last_Login', '2/28/09 9:54'),
#               ('Latitude', '38.4072222'),
#               ('Longitude', '27.1502778')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 23, 10, 4)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Kevin'),
#               ('City', 'Hollywood'),
#               ('State', 'CA'),
#               ('Country', 'United States'),
#               ('Account_Created', '5/30/06 20:25'),
#               ('Last_Login', '2/28/09 9:59'),
#               ('Latitude', '34.09833'),
#               ('Longitude', '-118.32583')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 19, 4, 55)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Alyssa'),
#               ('City', 'Brighton'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '2/19/08 9:27'),
#               ('Last_Login', '2/28/09 10:06'),
#               ('Latitude', '50.8333333'),
#               ('Longitude', '-0.15')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 28, 22, 2)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Hale'),
#               ('City', 'Hawera'),
#               ('State', 'Taranaki'),
#               ('Country', 'New Zealand'),
#               ('Account_Created', '1/23/09 22:31'),
#               ('Last_Login', '2/28/09 12:43'),
#               ('Latitude', '-39.5916667'),
#               ('Longitude', '174.2833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 4, 18, 57)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'KELI'),
#               ('City', 'Worongary'),
#               ('State', 'Queensland'),
#               ('Country', 'Australia'),
#               ('Account_Created', '12/23/08 15:17'),
#               ('Last_Login', '2/28/09 14:00'),
#               ('Latitude', '-28.05'),
#               ('Longitude', '153.35')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 20, 31)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Glen'),
#               ('City', 'Atlantida'),
#               ('State', 'Guatemala'),
#               ('Country', 'Guatemala'),
#               ('Account_Created', '1/6/09 16:53'),
#               ('Last_Login', '2/28/09 14:39'),
#               ('Latitude', '14.65'),
#               ('Longitude', '-90.4833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 24, 12, 0)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'T'),
#               ('City', 'El Escorial'),
#               ('State', 'Madrid'),
#               ('Country', 'Spain'),
#               ('Account_Created', '12/30/08 15:19'),
#               ('Last_Login', '2/28/09 15:17'),
#               ('Latitude', '40.5833333'),
#               ('Longitude', '-4.1166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 28, 11, 19)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'christal'),
#               ('City', 'Morrison'),
#               ('State', 'CO'),
#               ('Country', 'United States'),
#               ('Account_Created', '6/20/04 17:16'),
#               ('Last_Login', '2/28/09 17:18'),
#               ('Latitude', '39.65361'),
#               ('Longitude', '-105.19056')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 17, 48)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Alex'),
#               ('City', 'Augusta'),
#               ('State', 'GA'),
#               ('Country', 'United States'),
#               ('Account_Created', '6/10/05 20:25'),
#               ('Last_Login', '2/28/09 19:57'),
#               ('Latitude', '33.51722'),
#               ('Longitude', '-82.07583')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 23, 12, 42)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Anke'),
#               ('City', 'Avalon'),
#               ('State', 'New South Wales'),
#               ('Country', 'Australia'),
#               ('Account_Created', '3/3/08 17:38'),
#               ('Last_Login', '2/28/09 22:26'),
#               ('Latitude', '-33.6333333'),
#               ('Longitude', '151.3333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 7, 19, 48)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'TRICIA'),
#               ('City', 'Sydney'),
#               ('State', 'New South Wales'),
#               ('Country', 'Australia'),
#               ('Account_Created', '9/21/08 20:49'),
#               ('Last_Login', '3/1/09 0:14'),
#               ('Latitude', '-33.8833333'),
#               ('Longitude', '151.2166667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 26, 11, 19)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'smith'),
#               ('City', 'Lahti'),
#               ('State', 'Etela-Suomen Laani'),
#               ('Country', 'Finland'),
#               ('Account_Created', '1/4/09 5:25'),
#               ('Last_Login', '3/1/09 0:39'),
#               ('Latitude', '60.9666667'),
#               ('Longitude', '25.6666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 5, 13, 23)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Macy'),
#               ('City', 'Inner City'),
#               ('State', 'Vienna'),
#               ('Country', 'Austria'),
#               ('Account_Created', '1/5/09 11:28'),
#               ('Last_Login', '3/1/09 2:28'),
#               ('Latitude', '48.2166667'),
#               ('Longitude', '16.3666667')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 26, 13, 41)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Mastercard'),
#               ('Name', 'Lesleigh'),
#               ('City', 'Baden'),
#               ('State', 'Aargau'),
#               ('Country', 'Switzerland'),
#               ('Account_Created', '10/23/05 9:23'),
#               ('Last_Login', '3/1/09 3:11'),
#               ('Latitude', '47.4666667'),
#               ('Longitude', '8.3')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 20, 10, 42)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'esther'),
#               ('City', 'Huddersfield'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '1/20/09 9:15'),
#               ('Last_Login', '3/1/09 3:29'),
#               ('Latitude', '53.65'),
#               ('Longitude', '-1.7833333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 22, 14, 25)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Hans-Joerg'),
#               ('City', 'Belfast'),
#               ('State', 'Northern Ireland'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '11/10/08 12:15'),
#               ('Last_Login', '3/1/09 3:37'),
#               ('Latitude', '54.5833333'),
#               ('Longitude', '-5.9333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 28, 5, 36)),
#               ('Product', 'Product2'),
#               ('Price', 3600.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Christiane'),
#               ('City', 'Black River'),
#               ('State', 'Black River'),
#               ('Country', 'Mauritius'),
#               ('Account_Created', '1/9/09 8:10'),
#               ('Last_Login', '3/1/09 4:40'),
#               ('Latitude', '-20.3602778'),
#               ('Longitude', '57.3661111')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 1, 4, 24)),
#               ('Product', 'Product3'),
#               ('Price', 7500.0),
#               ('Payment_Type', 'Amex'),
#               ('Name', 'Pamela'),
#               ('City', 'Skaneateles'),
#               ('State', 'NY'),
#               ('Country', 'United States'),
#               ('Account_Created', '12/28/08 17:28'),
#               ('Last_Login', '3/1/09 7:21'),
#               ('Latitude', '42.94694'),
#               ('Longitude', '-76.42944')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 8, 11, 55)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Diners'),
#               ('Name', 'julie'),
#               ('City', 'Haverhill'),
#               ('State', 'England'),
#               ('Country', 'United Kingdom'),
#               ('Account_Created', '11/29/06 13:31'),
#               ('Last_Login', '3/1/09 7:28'),
#               ('Latitude', '52.0833333'),
#               ('Longitude', '0.4333333')]),
#  OrderedDict([('Transaction_date', datetime.datetime(2009, 1, 12, 21, 30)),
#               ('Product', 'Product1'),
#               ('Price', 1200.0),
#               ('Payment_Type', 'Visa'),
#               ('Name', 'Julia'),
#               ('City', 'Madison'),
#               ('State', 'WI'),
#               ('Country', 'United States'),
#               ('Account_Created', '11/17/08 22:24'),
#               ('Last_Login', '3/1/09 10:14'),
#               ('Latitude', '43.07306'),
#               ('Longitude', '-89.40111')])]

# %%
#df.sort_by('Price', aescending = False)

# %%
print('max price:',df.max('Price'))
print('min price:',df.min('Price'))
print('mean price:',df.mean('Price'))
print('max date:',df.max('Transaction_date'))
print('min date:',df.min('Transaction_date'))
#print('mean date:',df.mean('Transaction_date'))
print('exception', df.max('Payment_Type'))
# Out:
# max price: 13000.0
# min price: 250.0
# mean price: 1633.7675350701402
# max date: 2009-01-31 23:09:00
# min date: 2009-01-01 01:26:00
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-74-545d4152d880> in <module>()
#       5 print('min date:',df.min('Transaction_date'))
#       6 #print('mean date:',df.mean('Transaction_date'))
# ----> 7 print('exception', df.max('Payment_Type'))
#
# <ipython-input-69-f11e7f48b11a> in max(self, column_name)
#     120     def max(self, column_name):
#     121         if not self.type_valid(column_name):
# --> 122             raise Exception("Data Invalid Error")
#     123         return max(self[column_name])
#     124
#
# Exception: Data Invalid Error

# %%
infile = open('/Users/Lucinda/Desktop/660/data_source/SalesJan2009.csv')
lines = infile.readlines()
lines = [lines[i].strip('\n') for i in range(len(lines))]
data = [l.split(',') for l in lines]
lines[559]
# Out:
# '1/28/09 18:00,Product1,"13,000",Visa,sandhya,Centennial                  ,CO,United States,12/2/06 23:24,2/7/09 15:18,39.57917,-104.87639'

# %%
new_rows = [[datetime(2011, 1, 28, 18, 0),
             'Product1',
              33000,
             'Visa',
             'sandhya',
             'Centennial',
             'CO',
             'United States',
             '12/2/06 23:24',
             '2/7/09 15:18',
             '39.57917',
             '-104.87639'],

             [datetime(2013, 1, 28, 18, 0),
             'Product1',
              36000,
             'Visa',
             'sandhya',
             'Centennial',
             'CO',
             'United States',
             '12/2/06 23:24',
             '2/7/09 15:18',
             '39.57917',
             '-104.87639'],
]
df.add_rows(new_rows)
df[-1]
# Out:
# OrderedDict([('Transaction_date', datetime.datetime(2013, 1, 28, 18, 0)),
#              ('Product', 'Product1'),
#              ('Price', 36000),
#              ('Payment_Type', 'Visa'),
#              ('Name', 'sandhya'),
#              ('City', 'Centennial'),
#              ('State', 'CO'),
#              ('Country', 'United States'),
#              ('Account_Created', '12/2/06 23:24'),
#              ('Last_Login', '2/7/09 15:18'),
#              ('Latitude', '39.57917'),
#              ('Longitude', '-104.87639')])

# %%
new_column = list(range(len(df.data)))
df.add_column(new_column, 'new_column')
